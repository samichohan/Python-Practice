# %% [raw]
# LOOP
# while loops and for loops repeat again and again

# %%
count = 1
while count <= 5 :
    print("hello")
    count += 1
print(count)

# %%
i = 1
while i <= 100:
    print("Mr supra",i)
    i+=1

# %%
# print number from 1 to 100
i = 1
while i <= 5:
    print(i)
    i +=1
print("loop ended")

# %%
i = 5
while i >= 1:
    print(i)
    i -=1
print("loop ended")

# %%
i = 1
while i <= 10:
    print(i)
    i += 1

# %%
i = 10
while i >= 1:
    print(i)
    i-=1

# %%
n = int(input("Enter your number : "))
i = 1
while i <= 10:
    print(n*i)
    i += 1

# %%
#nums = [1,4,9,16,25,36,49,64,81,100]
heroes = ["ironman","thor","superman","batman"]
idx = 0
while idx < len(heroes):
    print(heroes[idx])
    idx += 1

# %%
nums = [1,4,9,16,25,36,49,64,81,100,36]

x = 36

i = 0
while i < len(nums):
    if(nums[i] == x):
        print("found at idx",i)
    else:
        print("finding..")
    
    i += 1

# %% [raw]
# break,continue

# %%
i = 1
while i <= 5:
    print(i)
    if(i== 3):
        break
    i += 1
print("end of loop")

# %%
nums = [1,4,9,16,25,36,49,64,81,100,36]

x = 36

i = 0
while i < len(nums):
    if(nums[i] == x):
       print("found at idx",i)
       break
    
    else:
        print("finding..")
    
    i += 1

print("end of loop")

# %%
i = 0 
while i <= 5:
    if(i == 3):
        i+= 1
        continue # skip
    print(i)
    i += 1

# %% [raw]
# FOR LOOP      SEQUENCE TRAVERSAL

# %%
nums = [1,2,3,4]

for val in nums:
    print(val)

# %%
veggies = ["potato","cucumber","brinjal","lady finger"]

for val in veggies:
    print(val)

# %%
tup = [1,2,3,4,2,8,9]

for num in tup:
    print(num)

# %%
str = "apnacollege"

for char in str:
    print(char)

# %%
str = "apnacollege"

for char in str:
    print(char)
else:
    print("end")

# %%
str = "apnacollege"

for char in str:
    if(char == "o"):
        print("o found")
        break
    print(char)

print("end")

# %%
nums = [1,4,9,25,36,49,64,81,100]

for el in nums:
    print(el)

# %%
nums = [1,4,9,16,25,36,49,64,81,100,49]
x = 49
idx = 0
for el in nums:
    if(el ==x):
        print("number found at idx", idx)
    idx += 1

# %%
nums = [1,4,9,16,25,36,49,64,81,100,49]
x = 49
idx = 0
for el in nums:
    if(el ==x):
        print("number found at idx", idx)
        break
    idx += 1

# %% [raw]
# range function(start,stop,step) start(0)

# %%
for i in range(5): # range(stop)
    print(i)

# %%
for i in range(2,10): # range(start,stop)
    print(i)

# %%
for i in range(2,10,2): # range(start,stop,step)
    print(i)

# %%
for i in range(2,20,2): # even number
    print(i)

# %%
for i in range(1,20,2): # odd number
    print(i)

# %%
for i in range(1,101):
    print(i)

# %%
for i in range(100,0,-1):
    print(i)

# %%
n = int(input("Enter number : "))

for i in range(1,11):
    print(n*i)

# %% [raw]
# pass statement:

# %%
for i in range(5):
    pass
print("some useful work")

# %%
n = 5
,
for i  in range(1, n+1):
    print(i)

# %%
n = 7
sum = 0
for i  in range(1, n+1):
    sum += i
print("total sum =", sum)

# %% [markdown]
# KODE GURUKAL PRACTICE

# %%
name = "Logical python"

for i in name:
    print(i)

# %%
numbers = [1,2,3,4,5,6,7]

for num in numbers:
    if num == 5:
        print("lucky number")
    else:
        print(num)

# %%
for i in range(101):
    print(i)

# %%
for i in range(1,5,2):
    print(i)

# %%
i = 0
while i <= 5:
    print(i)
    i += 1
print("end")

# %%
name = "Steve"
i = 0
while i<len(name):
    print(name[i])
    i += 1

# %%
orig_password = "abcd"

password = input("Enter password:")

while orig_password !=password:
    print("invalid password.")
    password = input("Enter password:")

print("welcome")

# %%
i = 5
while i >= 0:
    print(i)
    i -= 1

# %%
 for i in range (1,6):
     print(i)

# %%
for i in range (1,6):
     print(i)
     if i == 3:
         break
print("thanks")

# %%
i = 1

while i <= 5:
    print(i)
    i += 1

    if i == 3:
        break

# %%
i = 1

while i <= 5:
    print(i)

    if i == 3:
        break
    i += 1

# %%
for i in range (1,6):
     if i == 3:
         continue
     print(i)
    
print("thanks")

# %%
i = 0

while i <= 5:
    
    i += 1
    if i == 3:
        continue
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %%
orig_password = "abcd"

for i in range (1,6):
    password = input ("Enter password:")
    if orig_password == password:
        print("login successful")
        break
    print("you have",5,"attemps left.")
# Out:
# Enter password: jhjfjf
# you have 5 attemps left.
# Enter password: jcjj
# you have 5 attemps left.
# Enter password: abcd
# login successful
