# %% [raw]
# STRING FUNCTION

# %%
#len----> simply returns the number of charater in the string
print(len("i am"))
# Out:
# 4

# %%
print(ord("a"))
# Out:
# 97

# %%
print(chr(97))
# Out:
# a

# %%
# capitalize ---> converts the first character at the string to the upper case and remaining string

str = "hello WORld"

print(str.capitalize())
# Out:
# Hello world

# %%
#center--> return the centered string adding fill character to right and left

str="Sami"
print(str.center(10,"x"))
# Out:
# xxxSamixxx

# %%
#count
str="Hello Sami, How are you"

print(str.count('o'))
# Out:
# 3

# %%
#count 

str="Hello Sami, How are you"

print(str.count('o',1,7))
# Out:
# 1

# %%
#endswith---> check if a string ends with specified charactr(&)

str="Hello Sami, How are you?"

print(str.endswith("?"))
# Out:
# True

# %%
str="Hello Sami, How are you?"

print(str.endswith("u"))
# Out:
# False

# %%
#Expandtabs()--> expand the tabs (\t) with a specified number of spaces
str="Hello Sami, How are you?"

print(str.endswith("u"))
# Out:
# Hello            World

# %%
#find--> find specified character (&) from a string

str="Hello Sami, How are you?"

print(str.find("Sami"))
# Out:
# 6

# %%
#Index-->index location of a substring from a string 

str="Hello Sami, How are you?"

print(str.index("Sami"))
# Out:
# 6

# %%
str="Hello Sami, How are you?"

print(str.index("Samis"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 3
#       1 str="Hello Sami, How are you?"
# ----> 3 print(str.index("Samis"))
#
# ValueError: substring not found

# %%
#isdigit--> checks if the variable contains only digits

str="Hello Sami, How are you?"

print(str.isdigit())
# Out:
# False

# %%
str="1234"

print(str.isdigit())
# Out:
# True

# %%
#isspace--> checj if the string is just a white spaced (&)
str="    "

print(str.isspace())
# Out:
# True

# %%
str="    "

print(str.isspace())
# Out:
# False

# %%
#istitle--> check if the string is a title or not
str="Hello Sami,How are you"

print(str.istitle())
# Out:
# False

# %%
str="Hello Sami,How Are You"

print(str.istitle())
# Out:
# True

# %%
#isupper
str="Hello Sami,How Are You"

print(str.isupper())
# Out:
# False

# %%
str="HELLO SAMI,HOW ARE YOU"

print(str.isupper())
# Out:
# True

# %%
#join--> join each character of the string with the new string
str="HELLO"

print(('S').join(str))
# Out:
# HSESLSLSO

# %%
#lower
str="HELLO"

print(str.lower())
# Out:
# hello

# %%
#lstrip--> to remove the left white spaces from the string
str="                            HELLO"

print(str.lstrip())
# Out:
# HELLO

# %%
str="abc  xyz      HELLO"

print(str.lstrip('abc'))
# Out:
#   xyz      HELLO

# %%
#replace-->to replace character (&) from the string with a new character (&)
str="abc  xyz      HELLO"

print(str.replace('abc','Sami'))
# Out:
# Sami  xyz      HELLO

# %%
str="abc  xyz      HELLO"

print(str.replace('L','l'))
# Out:
# abc  xyz      HEllO

# %%
#rstrip--> to remove the right  white spaces from the string
str="abc   xyz   HELLO"

print(str.rstrip('HELLO'))
# Out:
# abc   xyz

# %%
#split---> split the string based on the seperator
str="abc xyz HELLO"

print(str.split())
# Out:
# ['abc', 'xyz', 'HELLO']

# %%
str="abc xyz HELLO"

print(str.split('xyz'))
# Out:
# ['abc ', ' HELLO']

# %%
str="abc|xyz|HELLO"

print(str.split('|'))
# Out:
# ['abc', 'xyz', 'HELLO']

# %%
#startswith--> to check if string starts with specified character(&)
str="abc xyz HELLO"

print(str.startswith('a'))
# Out:
# True

# %%
#strip---> to remove white spaces from both sides of the string
str="       abc xyz HELLO      "

print(str.strip())
# Out:
# abc xyz HELLO

# %%
#swapcase---> swape the lower case character to upper and uppercase to lower
str="abc xyz HELLO"

print(str.swapcase())
# Out:
# ABC XYZ hello

# %%
#title---> the first character of each word is converted to upper case
str="abc xyz HELLO"

print(str.title())
# Out:
# Abc Xyz Hello

# %%
#upper---> to converts all character of the string to the upper case
str="abc xyz HELLO"

print(str.upper())
# Out:
# ABC XYZ HELLO

# %% [raw]
# PRACTICE KODE GURUKUL

# %%
str="Logical python is The Best"

print(str.title())
# Out:
# Logical Python Is The Best

# %%
str="Logical python is The Best"

result=(str.replace('Logical','LOGICAL').replace('Best','BEST'))
print(result)
# Out:
# LOGICAL python is The BEST

# %%
str="Logical Python"

print(str[::3])
# Out:
# Lilyo

# %%
str="Logical Python"

print(str[-0])
# Out:
# L

# %%
a1="Logical Python"
a2="Logical Python"

print(id(a1)==id(a2))
# Out:
# True

# %%
a1="Logical"
a2="Logical"

print(id(a1)==id(a2))
# Out:
# True

# %%
a1="Logical$"
a2="Logical$"

print(id(a1)==id(a2))
# Out:
# False

# %% [raw]
# APNA COLLEGE PRACTICE FUNCTION

# %%
#functions
#endswith--> return true if string ends wiht substr
str= "I am studying python from apna college"

print(str.endswith('college'))
# Out:
# True

# %%
#capitalize--> capitalize 1st char
str= "i am studying python from apna college"

print(str.capitalize())
# Out:
# I am studying python from apna college

# %%
#isalnum--> alphabat and num true agar special character false return
str= "HelloWorld14256273"

print(str.isalnum())
# Out:
# True

# %%
#replace--> replace all occurrences of old from new
str= "I am studying python from apna college"

print(str.replace('o','a'))
# Out:
# I am studying pythan fram apna callege

# %%
str= "I am studying python from apna college"

print(str.replace('python','javascript'))
# Out:
# I am studying javascript from apna college

# %%
#find---> returns 1st index of 1st chareacter
str= "I am studying python from apna college"

print(str.find('python'))
# Out:
# 14

# %%
#count--> counts the occurences of substr
str= "I am studying python from apna college"

print(str.count('o'))
# Out:
# 3

# %% [raw]
# practice

# %%
name= input("enter your name: ")
print("length of your name is", len(name))
# Out:
# enter your name:  Sami
# length of your name is 4

# %%
str="$S$a$m$i$"
print(str.count('$'))
# Out:
# 5
