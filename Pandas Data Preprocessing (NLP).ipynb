# %% [markdown]
# Ws Cube : Channel:

# %% [markdown]
# Text Pre-processing:

# %% [raw]
# 1.Text Cleaning: In-text cleaning we do HTML tag removing , emoji handling , spelling checker , etc
# Basic Preprocessing : in basic preprocessing we do tokenization (word or sent tokenization , stop word removal
# ,digit reomval , lower casing.
# 2. Advance Preprocessing : in this step we do POS tagging , parsing and Coreference resolution>

# %% [markdown]
# Understanding Textual Data:

# %% [raw]
#                             Textual Data
# Elements of Text :
# . Hierarchy of Text
# . Tokens
# . Vocabulary
# . Punctuation
# . Part of speech
# . Root of a word
# . Base of a word
# . stop words.

# %%
x = " Natural language processing has its roots in the 1950s.[2] Already in 1950, Alan Turing publishedan article titled Computing Machinery and Intelligence which proposed what is now called the Turing teas a criterion of intelligence, though at the time that was not articulated as a problem separate fromartificial intelligence. Natural language processing has its roots in the 1950s.[2] Already in 1950, Alan Turing published an article titled Computing Machinery and Intelligence which proposed what is now called the Turing test as a criterion of intelligence, though at the time that was not articulated as a problem separate from artificial intelligence. "

# %% [markdown]
# Text Pre-processing Techniques:

# %% [raw]
# . Lower casing               . Tokenization
# . Remove HTML Tags           .Stop words Removal
# . Removing URLs              . N-Grams
# . Removing Punctuation       . Stemming\Lemmatization
# . Chat word Treatment
# . Spelling Correction

# %% [markdown]
# Tokenization:

# %%
var = " Natural language processing has its roots in the 1950s.[2] Already in 1950, Alan Turing publishedan .article titled Computing Machinery and Intelligence which proposed what is .now called the Turing teas a criterion of intelligence, though at the time .that was not articulated as a problem separate fromartificial intelligence. Natural language processing has its roots in the 1950s.[2] Already in 1950. Alan Turing published an article titled Computing Machinery and Intelligence which proposed what. is now called the Turing test as a criterion of intelligence, though at the time that was not articulated as a problem separate from artificial intelligence. "

# %%
var
# Out:
# ' Natural language processing has its roots in the 1950s.[2] Already in 1950, Alan Turing publishedan .article titled Computing Machinery and Intelligence which proposed what is .now called the Turing teas a criterion of intelligence, though at the time .that was not articulated as a problem separate fromartificial intelligence. Natural language processing has its roots in the 1950s.[2] Already in 1950. Alan Turing published an article titled Computing Machinery and Intelligence which proposed what. is now called the Turing test as a criterion of intelligence, though at the time that was not articulated as a problem separate from artificial intelligence. '

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
sent = sent_tokenize(var)

# %%
sent
# Out:
# [' Natural language processing has its roots in the 1950s.',
#  '[2] Already in 1950, Alan Turing publishedan .article titled Computing Machinery and Intelligence which proposed what is .now called the Turing teas a criterion of intelligence, though at the time .that was not articulated as a problem separate fromartificial intelligence.',
#  'Natural language processing has its roots in the 1950s.',
#  '[2] Already in 1950.',
#  'Alan Turing published an article titled Computing Machinery and Intelligence which proposed what.',
#  'is now called the Turing test as a criterion of intelligence, though at the time that was not articulated as a problem separate from artificial intelligence.']

# %%
for i in sent:
    print(i)
    print()
# Out:
#  Natural language processing has its roots in the 1950s.
#
# [2] Already in 1950, Alan Turing publishedan .article titled Computing Machinery and Intelligence which proposed what is .now called the Turing teas a criterion of intelligence, though at the time .that was not articulated as a problem separate fromartificial intelligence.
#
# Natural language processing has its roots in the 1950s.
#
# [2] Already in 1950.
#
# Alan Turing published an article titled Computing Machinery and Intelligence which proposed what.
#
# is now called the Turing test as a criterion of intelligence, though at the time that was not articulated as a problem separate from artificial intelligence.

# %%
word = word_tokenize(var)

# %%
word
# Out:
# ['Natural',
#  'language',
#  'processing',
#  'has',
#  'its',
#  'roots',
#  'in',
#  'the',
#  '1950s',
#  '.',
#  '[',
#  '2',
#  ']',
#  'Already',
#  'in',
#  '1950',
#  ',',
#  'Alan',
#  'Turing',
#  'publishedan',
#  '.article',
#  'titled',
#  'Computing',
#  'Machinery',
#  'and',
#  'Intelligence',
#  'which',
#  'proposed',
#  'what',
#  'is',
#  '.now',
#  'called',
#  'the',
#  'Turing',
#  'teas',
#  'a',
#  'criterion',
#  'of',
#  'intelligence',
#  ',',
#  'though',
#  'at',
#  'the',
#  'time',
#  '.that',
#  'was',
#  'not',
#  'articulated',
#  'as',
#  'a',
#  'problem',
#  'separate',
#  'fromartificial',
#  'intelligence',
#  '.',
#  'Natural',
#  'language',
#  'processing',
#  'has',
#  'its',
#  'roots',
#  'in',
#  'the',
#  '1950s',
#  '.',
#  '[',
#  '2',
#  ']',
#  'Already',
#  'in',
#  '1950',
#  '.',
#  'Alan',
#  'Turing',
#  'published',
#  'an',
#  'article',
#  'titled',
#  'Computing',
#  'Machinery',
#  'and',
#  'Intelligence',
#  'which',
# ...

# %%
for i in word:
    print(i)
# Out:
# Natural
# language
# processing
# has
# its
# roots
# in
# the
# 1950s
# .
# [
# 2
# ]
# Already
# in
# 1950
# ,
# Alan
# Turing
# publishedan
# .article
# titled
# Computing
# Machinery
# and
# Intelligence
# which
# proposed
# what
# is
# .now
# called
# the
# Turing
# teas
# a
# criterion
# of
# intelligence
# ,
# though
# at
# the
# time
# .that
# was
# not
# articulated
# as
# a
# problem
# separate
# fromartificial
# intelligence
# .
# Natural
# language
# processing
# has
# its
# roots
# in
# the
# 1950s
# .
# [
# 2
# ]
# Already
# in
# 1950
# .
# Alan
# Turing
# published
# an
# article
# titled
# Computing
# Machinery
# and
# Intelligence
# which
# proposed
# what
# .
# is
# now
# called
# the
# Turing
# test
# as
# a
# criterion
# of
# intelligence
# ,
# though
# at
# the
# time
# that
# was
# not
# articulated
# as
# a
# problem
# separate
# from
# artificial
# intelligence
# .

# %% [markdown]
# Stop Words Removal:

# %%
var
# Out:
# ' Natural language processing has its roots in the 1950s.[2] Already in 1950, Alan Turing publishedan .article titled Computing Machinery and Intelligence which proposed what is .now called the Turing teas a criterion of intelligence, though at the time .that was not articulated as a problem separate fromartificial intelligence. Natural language processing has its roots in the 1950s.[2] Already in 1950. Alan Turing published an article titled Computing Machinery and Intelligence which proposed what. is now called the Turing test as a criterion of intelligence, though at the time that was not articulated as a problem separate from artificial intelligence. '

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
var_new = word_tokenize(var)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\123/nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
from string import punctuation

# %%
stop = stopwords.words('english')

# %%
stop_word_list = list(punctuation)+stop

# %%
for i in var_new:
    if i not in stop_word_list:
        print(i)
# Out:
# Natural
# language
# processing
# roots
# 1950s
# 2
# Already
# 1950
# Alan
# Turing
# publishedan
# .article
# titled
# Computing
# Machinery
# Intelligence
# proposed
# .now
# called
# Turing
# teas
# criterion
# intelligence
# though
# time
# .that
# articulated
# problem
# separate
# fromartificial
# intelligence
# Natural
# language
# processing
# roots
# 1950s
# 2
# Already
# 1950
# Alan
# Turing
# published
# article
# titled
# Computing
# Machinery
# Intelligence
# proposed
# called
# Turing
# test
# criterion
# intelligence
# though
# time
# articulated
# problem
# separate
# artificial
# intelligence

# %% [markdown]
# Stemming and Lemmatization:

# %%
from nltk.stem import PorterStemmer

# %%
p = PorterStemmer()

# %%
p.stem('change')
# Out:
# 'chang'

# %% [markdown]
# Lemmatization:

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\123/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer

# %%
wl = WordNetLemmatizer()

# %%
wl.lemmatize("mice")
# Out:
# 'mouse'

# %% [markdown]
# Sheriyans AI School: Channel

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\123\Desktop\train.txt',sep = ';',header=None,names=['text','emotion'])

# %%
df.head()
# Out:
#                                                 text  emotion
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3  i am ever feeling nostalgic about the fireplac...     love
# 4                               i am feeling grouchy    anger

# %%
df.isnull().sum()
# Out:
# text       0
# emotion    0
# dtype: int64

# %%
unique_emotions=df['emotion'].unique()
emotion_numbers= {}
i = 0
for emo in unique_emotions:
    emotion_numbers[emo] = i
    i +=1
df['emotion'] = df['emotion'].map(emotion_numbers)

# %%
df
# Out:
#                                                     text  emotion
# 0                                i didnt feel humiliated        0
# 1      i can go from feeling so hopeless to so damned...        0
# 2       im grabbing a minute to post i feel greedy wrong        1
# 3      i am ever feeling nostalgic about the fireplac...        2
# 4                                   i am feeling grouchy        1
# ...                                                  ...      ...
# 15995  i just had a very brief time in the beanbag an...        0
# 15996  i am now turning and i feel pathetic that i am...        0
# 15997                     i feel strong and good overall        5
# 15998  i feel like this was such a rude comment and i...        1
# 15999  i know a lot but i feel so stupid because i ca...        0
#
# [16000 rows x 2 columns]

# %% [markdown]
# Text Cleaning:

# %% [markdown]
# 1.Lowercasing:

# %%
df['text']=df['text'].apply(lambda x: x.lower())

# %%
df
# Out:
#                                                     text  emotion
# 0                                i didnt feel humiliated        0
# 1      i can go from feeling so hopeless to so damned...        0
# 2       im grabbing a minute to post i feel greedy wrong        1
# 3      i am ever feeling nostalgic about the fireplac...        2
# 4                                   i am feeling grouchy        1
# ...                                                  ...      ...
# 15995  i just had a very brief time in the beanbag an...        0
# 15996  i am now turning and i feel pathetic that i am...        0
# 15997                     i feel strong and good overall        5
# 15998  i feel like this was such a rude comment and i...        1
# 15999  i know a lot but i feel so stupid because i ca...        0
#
# [16000 rows x 2 columns]

# %% [markdown]
# 2.Remove Punctuation:

# %%
import string
from string import punctuation

# %%
def remove_punc(txt):
    return txt.translate(str.maketrans('','',string.punctuation))

# %%
df['text']=df['text'].apply(remove_punc)

# %%
df
# Out:
#                                                     text  emotion
# 0                                i didnt feel humiliated        0
# 1      i can go from feeling so hopeless to so damned...        0
# 2       im grabbing a minute to post i feel greedy wrong        1
# 3      i am ever feeling nostalgic about the fireplac...        2
# 4                                   i am feeling grouchy        1
# ...                                                  ...      ...
# 15995  i just had a very brief time in the beanbag an...        0
# 15996  i am now turning and i feel pathetic that i am...        0
# 15997                     i feel strong and good overall        5
# 15998  i feel like this was such a rude comment and i...        1
# 15999  i know a lot but i feel so stupid because i ca...        0
#
# [16000 rows x 2 columns]

# %% [markdown]
# 3.Remove Numbers:

# %%
def remove_numbers(txt):
    new = ""
    for i in txt:
        if not i.isdigit():
            new = new + i
    return new

df['text'] = df['text'].apply(remove_numbers)

# %%
df
# Out:
#                                                     text  emotion
# 0                                i didnt feel humiliated        0
# 1      i can go from feeling so hopeless to so damned...        0
# 2       im grabbing a minute to post i feel greedy wrong        1
# 3      i am ever feeling nostalgic about the fireplac...        2
# 4                                   i am feeling grouchy        1
# ...                                                  ...      ...
# 15995  i just had a very brief time in the beanbag an...        0
# 15996  i am now turning and i feel pathetic that i am...        0
# 15997                     i feel strong and good overall        5
# 15998  i feel like this was such a rude comment and i...        1
# 15999  i know a lot but i feel so stupid because i ca...        0
#
# [16000 rows x 2 columns]

# %% [markdown]
# 4.Remove URLs/Links:

# %% [markdown]
# 5.Remove HTML Tags:

# %% [markdown]
# 6.Remove Emojis & Special characters:

# %%
# def remove_numbers(txt):
#     new = ""
#     for i in txt:
#         if not i.isascii():
#             new = new + i
#     return new

# df['text'].apply(remove_numbers)
# Out:
# 0
# 1
# 2
# 3
# 4
#         ..
# 15995
# 15996
# 15997
# 15998
# 15999
# Name: text, Length: 16000, dtype: object

# %%
df
# Out:
#                                                     text  emotion
# 0                                i didnt feel humiliated        0
# 1      i can go from feeling so hopeless to so damned...        0
# 2       im grabbing a minute to post i feel greedy wrong        1
# 3      i am ever feeling nostalgic about the fireplac...        2
# 4                                   i am feeling grouchy        1
# ...                                                  ...      ...
# 15995  i just had a very brief time in the beanbag an...        0
# 15996  i am now turning and i feel pathetic that i am...        0
# 15997                     i feel strong and good overall        5
# 15998  i feel like this was such a rude comment and i...        1
# 15999  i know a lot but i feel so stupid because i ca...        0
#
# [16000 rows x 2 columns]

# %% [markdown]
# 7.Remove Stopwords:

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\123/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\123/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
df.loc[1,'text']
# Out:
# 'i can go from feeling so hopeless to so damned hopeful just from being around someone who cares and is awake'

# %%
def remove_stopwords(txt):
    words = txt.split()
    cleaned = []
    for i in words:
        if not i in stop_words:
            cleaned.append(i)

    return ' '.join(cleaned)

# %%
txt = 'This is Sami my name are sami is  and'
remove_stopwords(txt)
# Out:
# 'This Sami name sami'

# %%
df['text']=df['text'].apply(remove_stopwords)

# %%
df.loc[1]['text']
# Out:
# 'go feeling hopeless damned hopeful around someone cares awake'

# %% [markdown]
# CampusX: Channel

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\123\Desktop\IMDB Dataset.csv')

# %%
df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %%
df.describe()
# Out:
#                                                    review sentiment
# count                                               50000     50000
# unique                                              49582         2
# top     Loved today's show!!! It was a variety and not...  positive
# freq                                                    5     25000

# %%
df.duplicated().value_counts()
# Out:
# False    49582
# True       418
# Name: count, dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [49582 rows x 2 columns]

# %% [markdown]
# Preprocessing:

# %% [markdown]
# 1.Lowercasing:

# %%
df['review']=df['review'].str.lower()

# %%
df
# Out:
#                                                   review sentiment
# 0      one of the other reviewers has mentioned that ...  positive
# 1      a wonderful little production. <br /><br />the...  positive
# 2      i thought this was a wonderful way to spend ti...  positive
# 3      basically there's a family where a little boy ...  negative
# 4      petter mattei's "love in the time of money" is...  positive
# ...                                                  ...       ...
# 49995  i thought this movie did a down right good job...  positive
# 49996  bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  i am a catholic taught in parochial elementary...  negative
# 49998  i'm going to have to disagree with the previou...  negative
# 49999  no one expects the star trek movies to be high...  negative
#
# [49582 rows x 2 columns]

# %% [markdown]
# 2.Remove HTML tags:

# %%
import re

# %%
def remove_html_tags(text):
    pattern = re.compile('<.*?>')
    return pattern.sub(r'',text)

# %%
#test on example:
text = "<html><body><p> Movie 1</p><p> Actor - Aamir Khan </p></p> Click here to <a href-'http://google.com'> download"
remove_html_tags(text)
# Out:
# ' Movie 1 Actor - Aamir Khan  Click here to  download'

# %%
# apply on data set
df['review']=df['review'].apply(remove_html_tags)

# %%
df
# Out:
#                                                   review sentiment
# 0      one of the other reviewers has mentioned that ...  positive
# 1      a wonderful little production. the filming tec...  positive
# 2      i thought this was a wonderful way to spend ti...  positive
# 3      basically there's a family where a little boy ...  negative
# 4      petter mattei's "love in the time of money" is...  positive
# ...                                                  ...       ...
# 49995  i thought this movie did a down right good job...  positive
# 49996  bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  i am a catholic taught in parochial elementary...  negative
# 49998  i'm going to have to disagree with the previou...  negative
# 49999  no one expects the star trek movies to be high...  negative
#
# [49582 rows x 2 columns]

# %% [markdown]
# 3.Remove URLs Tags:

# %%
def remove_url_tags(text):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'',text)

# %%
#example
text = 'check out my notebook https://www.kaggle.com/campusx/notebook8223fc1abb'
remove_url_tags(text)
# Out:
# 'check out my notebook '

# %%
df['review']=df['review'].apply(remove_url_tags)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production. the filming tec...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically there's a family where a little boy ...  negative
# 4  petter mattei's "love in the time of money" is...  positive

# %% [markdown]
# 4.Remove Punctuations:

# %%
import nltk
import string
from string import punctuation

# %%
exclude = string.punctuation
print(exclude)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
def remove_punc(text):
    return text.translate(str.maketrans('','',exclude))

# %%
#exanple
text='s.a,m/,?i'
remove_punc(text)
# Out:
# 'sami'

# %%
df['review']=df['review'].apply(remove_punc)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production the filming tech...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically theres a family where a little boy j...  negative
# 4  petter matteis love in the time of money is a ...  positive

# %% [markdown]
# 5.Chat word treatment:

# %%
chatwords = {
    "AFAIK": "As Far As I Know",
    "AFK": "Away From Keyboard",
    "ASAP": "As Soon As Possible",
    "ATK": "At The Keyboard",
    "ATM": "At The Moment",
    "A3": "Anytime, Anywhere, Anyplace",
    "BAK": "Back At Keyboard",
    "BBL": "Be Back Later",
    "BBS": "Be Back Soon",
    "BFN": "Bye For Now",
    "B4N": "Bye For Now",
    "BRB": "Be Right Back",
    "BRT": "Be Right There",
    "BTW": "By The Way",
    "B4": "Before",
    "B4N": "Bye For Now",
    "CU": "See You",
    "CUL8R": "See You Later",
    "CYA": "See You",
    "FAQ": "Frequently Asked Questions",
    "FC": "Fingers Crossed",
    "FWIW": "For What It's Worth",
    "FYI": "For Your Information",
    "GAL": "Get A Life",
    "GG": "Good Game",
    "GN": "Good Night",
    "GMTA": "Great Minds Think Alike",
    "GR8": "Great!",
    "G9": "Genius",
    "IC": "I See",
    "ICQ": "I Seek you (also a chat program)",
    "ILU": "ILU: I Love You",
    "IMHO": "In My Honest/Humble Opinion",
    "IMO": "In My Opinion",
    "IOW": "In Other Words",
    "IRL": "In Real Life",
    "KISS": "Keep It Simple, Stupid",
    "LDR": "Long Distance Relationship",
    "LMAO": "Laugh My A.. Off",
    "LOL": "Laughing Out Loud",
    "LTNS": "Long Time No See",
    "L8R": "Later",
    "MTE": "My Thoughts Exactly",
    "M8": "Mate",
    "NRN": "No Reply Necessary",
    "OIC": "Oh I See",
    "PITA": "Pain In The A..",
    "PRT": "Party",
    "PRW": "Parents Are Watching",
    "QPSA": "Que Pasa?",
    "ROFL": "Rolling On The Floor Laughing",
    "ROFLOL": "Rolling On The Floor Laughing Out Loud",
    "ROTFLMAO": "Rolling On The Floor Laughing My A.. Off",
    "SK8": "Skate",
    "STATS": "Your sex and age",
    "ASL": "Age, Sex, Location",
    "THX": "Thank You",
    "TTFN": "Ta-Ta For Now!",
    "TTYL": "Talk To You Later",
    "U": "You",
    "U2": "You Too",
    "U4E": "Yours For Ever",
    "WB": "Welcome Back",
    "WTF": "What The F...",
    "WTG": "Way To Go!",
    "WUF": "Where Are You From?",
    "W8": "Wait...",
    "7K": "Sick:-D Laugher",
    "TFW": "That feeling when",
    "MFW": "My face when",
    "MRW": "My reaction when",
    "IFYP": "I feel your pain",
    "LOL": "Laughing out loud",
    "TNTL": "Trying not to laugh",
    "JK": "Just kidding",
    "IDC": "I don’t care",
    "ILY": "I love you",
    "IMU": "I miss you",
    "ADIH": "Another day in hell",
    "IDC": "I don’t care",
    "ZZZ": "Sleeping, bored, tired",
    "WYWH": "Wish you were here",
    "TIME": "Tears in my eyes",
    "BAE": "Before anyone else",
    "FIMH": "Forever in my heart",
    "BSAAW": "Big smile and a wink",
    "BWL": "Bursting with laughter",
    "LMAO": "Laughing my a** off",
    "BFF": "Best friends forever",
    "CSL": "Can’t stop laughing"
}

# %%
def chat_conversation(text):
    new_text=[]
    for word in text.split():
        if word.upper() in chatwords:
            new_text.append(chatwords[word.upper()])
        else:
            new_text.append(word)
    return ' '.join(new_text)

# %%
#Example test
text = 'IMHO he is the best'
chat_conversation(text)
# Out:
# 'In My Honest/Humble Opinion he is the best'

# %%
df['review']=df['review'].apply(chat_conversation)

# %%
df
# Out:
#                                                   review sentiment
# 0      one of the other reviewers has mentioned that ...  positive
# 1      a wonderful little production the filming tech...  positive
# 2      i thought this was a wonderful way to spend Te...  positive
# 3      basically theres a family where a little boy j...  negative
# 4      petter matteis love in the Tears in my eyes of...  positive
# ...                                                  ...       ...
# 49995  i thought this movie did a down right good job...  positive
# 49996  bad plot bad dialogue bad acting idiotic direc...  negative
# 49997  i am a catholic taught in parochial elementary...  negative
# 49998  im going to have to disagree with the previous...  negative
# 49999  no one expects the star trek movies to be high...  negative
#
# [49582 rows x 2 columns]

# %% [markdown]
# 6.spelling Correction:

# %%
# !pip install textblob
# Out:
# ...
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    --------------------------------- ------ 524.3/624.3 kB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 624.3/624.3 kB 2.1 MB/s eta 0:00:00
# ...

# %%
from textblob import TextBlob

# %%
def spell_correction(text):
    text_correct=TextBlob(text)
    return text_correct.correct().string

# %%
text = 'crtein condtions durringg severl generationnns aree modifid in the same mannir'
spell_correction(text)
# Out:
# 'certain conditions during several generations are modified in the same manner'

# %%
df['review']=df['review'].apply(spell_correction)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# 7.Stopwords:

# %%
import nltk

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
def remove_stopwords(text):
    new_text = []
    for word in text.split():
        if word.lower() in stopwords.words('english'):
            new_text.append('')
        else:
            new_text.append(word)
    return ' '.join(new_text)

# %%
#example
text = 'probably my all-time favourite movie, a story of selflessness ,this sami are'
remove_stopwords(text)
# Out:
# 'probably  all-time favourite movie,  story  selflessness ,this sami '

# %%
df['review']=df['review'].apply(remove_stopwords)

# %%
df.head()

# %% [markdown]
# 8.Handling Emojis:

# %%
import emoji
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import emoji
#
# ModuleNotFoundError: No module named 'emoji'

# %%
pip install emoji
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001F58E1738C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/emoji/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001F58E27C410>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/emoji/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001F58E27C690>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/emoji/
# ...

# %%
def replace_emojis(text):
    return emoji.demojize(text)

# %%
replace_emojis('Pyhton is 😎')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 replace_emojis('Pyhton is 😎')
#
# NameError: name 'replace_emojis' is not defined

# %%
print('fnh')
# Out:
# fnh

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\123\anaconda3_new9\python.exe
